# %% [markdown]
# # RL Stock Trading using DQN
# # This notebook runs on NVDAle Colab. It implements a custom Gym environment for single-stock trading,
# # computes common indicators, trains a DQN agent, and evaluates performance.

# %%
# !pip install --quiet yfinance gym==0.25.2 torch torchvision torchaudio pandas numpy matplotlib

# %%
import yfinance as yf
import gym
from gym import spaces
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque, namedtuple
import random

# %%
def fetch_data(symbol, start_date, end_date):
    df = yf.download(symbol, start=start_date, end=end_date)
    df = df[['Open', 'High', 'Low', 'Close', 'Volume']].dropna()
    return df

# %%

def add_indicators(df, window_sma=10, window_ema=10, window_rsi=14):
    df['SMA'] = df['Close'].rolling(window=window_sma).mean()
    df['EMA'] = df['Close'].ewm(span=window_ema, adjust=False).mean()
    # RSI calculation
    delta = df['Close'].diff()
    gain = delta.where(delta > 0, 0).rolling(window=window_rsi).mean()
    loss = -delta.where(delta < 0, 0).rolling(window=window_rsi).mean()
    rs = gain / loss
    df['RSI'] = 100 - (100 / (1 + rs))
    # Back-fill NaN values
    df.bfill(inplace=True)
    return df


# %%
class TradingEnv(gym.Env):
    """Custom Gym environment for single-stock trading"""
    NVDAdata = {'render.modes': ['human']}

    def __init__(self, df, initial_balance=10000, max_steps=200):
        super(TradingEnv, self).__init__()
        self.df = df.reset_index(drop=True)
        self.initial_balance = initial_balance
        self.max_steps = min(max_steps, len(df) - 1)

        # Actions: 0 = hold, 1 = buy 1 share, 2 = sell 1 share
        self.action_space = spaces.Discrete(3)
        # Observation: [close, SMA, EMA, RSI, holdings, cash]
        obs_low = np.array([0, 0, 0, 0, 0, 0], dtype=np.float32)
        obs_high = np.array([np.inf, np.inf, np.inf, 100, np.inf, np.inf], dtype=np.float32)
        self.observation_space = spaces.Box(obs_low, obs_high, dtype=np.float32)

    def reset(self):
        self.balance = float(self.initial_balance)
        self.net_worth = float(self.initial_balance)
        self.shares_held = 0
        self.current_step = 0
        return self._get_obs()

    def _get_obs(self):
        row = self.df.loc[self.current_step]
        return np.array([
            row['Close'].item(),
            row['SMA'].item(),
            row['EMA'].item(),
            row['RSI'].item(),
            float(self.shares_held),
            float(self.balance)
        ], dtype=np.float32)

    def step(self, action):
        row = self.df.loc[self.current_step]
        price = row['Close'].item()
        prev_net_worth = self.net_worth

        # Execute action
        if action == 1:  # buy
            if self.balance >= price:
                self.shares_held += 1
                self.balance -= price
        elif action == 2:  # sell
            if self.shares_held > 0:
                self.shares_held -= 1
                self.balance += price

        self.current_step += 1
        done = self.current_step >= self.max_steps
        row_next = self.df.loc[self.current_step]
        self.net_worth = self.balance + self.shares_held * row_next['Close'].item()
        reward = self.net_worth - prev_net_worth

        obs = self._get_obs()
        return obs, reward, done, {}

    def render(self, mode='human'):
        print(f"Step: {self.current_step}, Balance: {self.balance:.2f}, Shares: {self.shares_held}, Net Worth: {self.net_worth:.2f}")


# %%
class DQN(nn.Module):
    def __init__(self, input_dim, action_dim):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(input_dim, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, action_dim)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# %%
Transition = namedtuple('Transition', ('state', 'action', 'reward', 'next_state', 'done'))

class ReplayBuffer:
    def __init__(self, capacity=10000):
        self.memory = deque(maxlen=capacity)

    def push(self, *args):
        self.memory.append(Transition(*args))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)



# %%
# Hyperparameters
episode_count = 500
nb_steps = 200
gamma = 0.99
epsilon_start = 1.0
epsilon_end = 0.01
epsilon_decay = 500
batch_size = 64
target_update = 10

# Fetch and prepare data
df = fetch_data('NVDA', '2020-01-01', '2021-01-01')
df = add_indicators(df)

env = TradingEnv(df, initial_balance=10000, max_steps=200)

# Init networks and optimizer
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
policy_net = DQN(env.observation_space.shape[0], env.action_space.n).to(device)
target_net = DQN(env.observation_space.shape[0], env.action_space.n).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()
optimizer = optim.Adam(policy_net.parameters(), lr=1e-2)
memory = ReplayBuffer()

steps_done = 0

def select_action(state):
    global steps_done
    eps_threshold = epsilon_end + (epsilon_start - epsilon_end) * np.exp(-1. * steps_done / epsilon_decay)
    steps_done += 1
    if random.random() < eps_threshold:
        return random.randrange(env.action_space.n)
    with torch.no_grad():
        state_v = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
        q_values = policy_net(state_v)
        return q_values.argmax().item()

for episode in range(1, episode_count + 1):
    state = env.reset()
    total_reward = 0
    for t in range(nb_steps):
        action = select_action(state)
        next_state, reward, done, _ = env.step(action)
        memory.push(state, action, reward, next_state, done)
        state = next_state
        total_reward += reward

        # Learn from experience
        if len(memory) >= batch_size:
            transitions = memory.sample(batch_size)
            batch = Transition(*zip(*transitions))

            state_batch = torch.tensor(batch.state, dtype=torch.float32).to(device)
            action_batch = torch.tensor(batch.action).unsqueeze(1).to(device)
            reward_batch = torch.tensor(batch.reward, dtype=torch.float32).unsqueeze(1).to(device)
            next_state_batch = torch.tensor(batch.next_state, dtype=torch.float32).to(device)
            done_batch = torch.tensor(batch.done, dtype=torch.float32).unsqueeze(1).to(device)

            q_values = policy_net(state_batch).gather(1, action_batch)
            next_q_values = target_net(next_state_batch).max(1)[0].detach().unsqueeze(1)
            expected_q = reward_batch + (gamma * next_q_values * (1 - done_batch))

            loss = nn.MSELoss()(q_values, expected_q)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        if done:
            break

    if episode % target_update == 0:
        target_net.load_state_dict(policy_net.state_dict())
    print(f"Episode {episode}/{episode_count}, Total Reward: {total_reward:.2f}")



# %%
state = env.reset()
values = []
s = state
for _ in range(env.max_steps):
    action = policy_net(
        torch.tensor(s, dtype=torch.float32)
               .unsqueeze(0).to(device)
    ).argmax().item()
    s, _, done, _ = env.step(action)
    values.append(env.net_worth)
    if done:
        break

# Generate buy‑and‑hold values for the same number of steps:
bh_prices = df['Close'].iloc[:len(values)].values
bh_values  = bh_prices / bh_prices[0] * env.initial_balance

# Plot both on a shared 0–N axis:
plt.figure(figsize=(10, 5))
plt.plot(range(len(values)), values, label='DQN Portfolio Value')
plt.plot(range(len(bh_values)), bh_values, label='Buy and Hold')
plt.legend()
plt.title('Portfolio Value Over Time (aligned steps)')
plt.xlabel('Time Step')
plt.ylabel('Portfolio Value ($)')
plt.show()




# ## End of Notebook
# You can now experiment with parameters, different stocks, or add more indicators!
# Out:
# /tmp/ipython-input-2-4220673831.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-2-4220673831.py:171: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:254.)
#   state_batch = torch.tensor(batch.state, dtype=torch.float32).to(device)
# Episode 1/500, Total Reward: 30.73
# Episode 2/500, Total Reward: 4.18
# Episode 3/500, Total Reward: 17.44
# Episode 4/500, Total Reward: 21.23
# Episode 5/500, Total Reward: 19.23
# Episode 6/500, Total Reward: 9.60
# Episode 7/500, Total Reward: 20.48
# Episode 8/500, Total Reward: 23.66
# Episode 9/500, Total Reward: 24.30
# Episode 10/500, Total Reward: 63.16
# Episode 11/500, Total Reward: 56.06
# Episode 12/500, Total Reward: 7.22
# Episode 13/500, Total Reward: 28.22
# Episode 14/500, Total Reward: 85.03
# Episode 15/500, Total Reward: 27.75
# Episode 16/500, Total Reward: 24.54
# Episode 17/500, Total Reward: 16.28
# Episode 18/500, Total Reward: 73.86
# Episode 19/500, Total Reward: 17.30
# Episode 20/500, Total Reward: 85.43
# Episode 21/500, Total Reward: 269.17
# Episode 22/500, Total Reward: 194.92
# Episode 23/500, Total Reward: 26.98
# Episode 24/500, Total Reward: 128.86
# Episode 25/500, Total Reward: 4.27
# Episode 26/500, Total Reward: 38.26
# Episode 27/500, Total Reward: 39.32
# Episode 28/500, Total Reward: 66.68
# Episode 29/500, Total Reward: 58.75
# Episode 30/500, Total Reward: 143.98
# Episode 31/500, Total Reward: 10.63
# Episode 32/500, Total Reward: 38.44
# Episode 33/500, Total Reward: 43.47
# Episode 34/500, Total Reward: 48.50
# Episode 35/500, Total Reward: 88.59
# Episode 36/500, Total Reward: 93.11
# Episode 37/500, Total Reward: 75.78
# Episode 38/500, Total Reward: 29.94
# Episode 39/500, Total Reward: 25.80
# Episode 40/500, Total Reward: 33.17
# Episode 41/500, Total Reward: 30.77
# Episode 42/500, Total Reward: 77.44
# Episode 43/500, Total Reward: 25.41
# Episode 44/500, Total Reward: 43.85
# Episode 45/500, Total Reward: 24.48
# Episode 46/500, Total Reward: 26.38
# Episode 47/500, Total Reward: 39.90
# Episode 48/500, Total Reward: 39.13
# Episode 49/500, Total Reward: 14.33
# Episode 50/500, Total Reward: 35.49
# Episode 51/500, Total Reward: 34.00
# Episode 52/500, Total Reward: 122.23
# Episode 53/500, Total Reward: 26.10
# Episode 54/500, Total Reward: 9.45
# Episode 55/500, Total Reward: 147.71
# Episode 56/500, Total Reward: 26.42
# Episode 57/500, Total Reward: 44.89
# Episode 58/500, Total Reward: 62.63
# Episode 59/500, Total Reward: 61.10
# Episode 60/500, Total Reward: 36.47
# Episode 61/500, Total Reward: 22.68
# Episode 62/500, Total Reward: 109.65
# Episode 63/500, Total Reward: 46.83
# Episode 64/500, Total Reward: 31.72
# Episode 65/500, Total Reward: 66.37
# Episode 66/500, Total Reward: 24.89
# Episode 67/500, Total Reward: 73.20
# Episode 68/500, Total Reward: 58.18
# Episode 69/500, Total Reward: 76.71
# Episode 70/500, Total Reward: 11.41
# Episode 71/500, Total Reward: 9.76
# Episode 72/500, Total Reward: 79.01
# Episode 73/500, Total Reward: 19.41
# Episode 74/500, Total Reward: 77.18
# Episode 75/500, Total Reward: 65.26
# Episode 76/500, Total Reward: 16.15
# Episode 77/500, Total Reward: 81.11
# Episode 78/500, Total Reward: 13.26
# Episode 79/500, Total Reward: 26.22
# Episode 80/500, Total Reward: 53.67
# Episode 81/500, Total Reward: 51.57
# Episode 82/500, Total Reward: 42.17
# Episode 83/500, Total Reward: 59.20
# Episode 84/500, Total Reward: 57.08
# Episode 85/500, Total Reward: 275.87
# Episode 86/500, Total Reward: 33.59
# Episode 87/500, Total Reward: 57.44
# Episode 88/500, Total Reward: 69.88
# Episode 89/500, Total Reward: 67.09
# Episode 90/500, Total Reward: 43.43
# Episode 91/500, Total Reward: 123.74
# Episode 92/500, Total Reward: 67.80
# Episode 93/500, Total Reward: 100.30
# Episode 94/500, Total Reward: 88.87
# Episode 95/500, Total Reward: 121.73
# Episode 96/500, Total Reward: 30.22
# Episode 97/500, Total Reward: 55.79
# Episode 98/500, Total Reward: 42.50
# Episode 99/500, Total Reward: 25.26
# Episode 100/500, Total Reward: 47.88
# Episode 101/500, Total Reward: 115.49
# Episode 102/500, Total Reward: 35.00
# Episode 103/500, Total Reward: 90.66
# Episode 104/500, Total Reward: 22.92
# Episode 105/500, Total Reward: 37.69
# Episode 106/500, Total Reward: 127.37
# Episode 107/500, Total Reward: 32.27
# Episode 108/500, Total Reward: 38.05
# Episode 109/500, Total Reward: 15.79
# Episode 110/500, Total Reward: 40.91
# Episode 111/500, Total Reward: 41.22
# Episode 112/500, Total Reward: 40.20
# Episode 113/500, Total Reward: 102.61
# Episode 114/500, Total Reward: 14.44
# Episode 115/500, Total Reward: 15.39
# Episode 116/500, Total Reward: 46.72
# Episode 117/500, Total Reward: 71.82
# Episode 118/500, Total Reward: 156.45
# Episode 119/500, Total Reward: 151.49
# Episode 120/500, Total Reward: 202.70
# Episode 121/500, Total Reward: 76.01
# Episode 122/500, Total Reward: 52.62
# Episode 123/500, Total Reward: 89.30
# Episode 124/500, Total Reward: 32.67
# Episode 125/500, Total Reward: 32.60
# Episode 126/500, Total Reward: 37.80
# Episode 127/500, Total Reward: 39.73
# Episode 128/500, Total Reward: 51.42
# Episode 129/500, Total Reward: 43.39
# Episode 130/500, Total Reward: 94.30
# Episode 131/500, Total Reward: 76.15
# Episode 132/500, Total Reward: 27.44
# Episode 133/500, Total Reward: 193.59
# Episode 134/500, Total Reward: 95.75
# Episode 135/500, Total Reward: 88.77
# Episode 136/500, Total Reward: 225.79
# Episode 137/500, Total Reward: 132.52
# Episode 138/500, Total Reward: 55.17
# Episode 139/500, Total Reward: 27.86
# Episode 140/500, Total Reward: 61.01
# Episode 141/500, Total Reward: 167.33
# Episode 142/500, Total Reward: 99.25
# Episode 143/500, Total Reward: 128.69
# Episode 144/500, Total Reward: 121.84
# Episode 145/500, Total Reward: 187.86
# Episode 146/500, Total Reward: 89.52
# Episode 147/500, Total Reward: 134.75
# Episode 148/500, Total Reward: 178.44
# Episode 149/500, Total Reward: 138.06
# Episode 150/500, Total Reward: 127.71
# Episode 151/500, Total Reward: 258.09
# Episode 152/500, Total Reward: 189.94
# Episode 153/500, Total Reward: 258.11
# Episode 154/500, Total Reward: 192.18
# Episode 155/500, Total Reward: 127.12
# Episode 156/500, Total Reward: 167.89
# Episode 157/500, Total Reward: 60.93
# Episode 158/500, Total Reward: 146.87
# Episode 159/500, Total Reward: 214.76
# Episode 160/500, Total Reward: 64.19
# Episode 161/500, Total Reward: 182.51
# Episode 162/500, Total Reward: 44.56
# Episode 163/500, Total Reward: 48.04
# Episode 164/500, Total Reward: 233.54
# Episode 165/500, Total Reward: 165.60
# Episode 166/500, Total Reward: 124.31
# Episode 167/500, Total Reward: 291.37
# Episode 168/500, Total Reward: 205.90
# Episode 169/500, Total Reward: 148.86
# Episode 170/500, Total Reward: 153.50
# Episode 171/500, Total Reward: 177.79
# Episode 172/500, Total Reward: 79.02
# Episode 173/500, Total Reward: 108.33
# Episode 174/500, Total Reward: 119.59
# Episode 175/500, Total Reward: 98.25
# Episode 176/500, Total Reward: 325.37
# Episode 177/500, Total Reward: 94.89
# Episode 178/500, Total Reward: 88.78
# Episode 179/500, Total Reward: 225.45
# Episode 180/500, Total Reward: 294.86
# Episode 181/500, Total Reward: 79.55
# Episode 182/500, Total Reward: 76.61
# Episode 183/500, Total Reward: 176.32
# Episode 184/500, Total Reward: 181.61
# Episode 185/500, Total Reward: 120.68
# Episode 186/500, Total Reward: 52.65
# Episode 187/500, Total Reward: 119.14
# Episode 188/500, Total Reward: 332.25
# Episode 189/500, Total Reward: 206.11
# Episode 190/500, Total Reward: 46.19
# Episode 191/500, Total Reward: 328.82
# Episode 192/500, Total Reward: 138.39
# Episode 193/500, Total Reward: 368.69
# Episode 194/500, Total Reward: 205.76
# Episode 195/500, Total Reward: 266.34
# Episode 196/500, Total Reward: 183.34
# Episode 197/500, Total Reward: 190.16
# Episode 198/500, Total Reward: 132.62
# Episode 199/500, Total Reward: 65.01
# Episode 200/500, Total Reward: 255.10
# Episode 201/500, Total Reward: 363.35
# Episode 202/500, Total Reward: 444.83
# Episode 203/500, Total Reward: 117.91
# Episode 204/500, Total Reward: 288.98
# Episode 205/500, Total Reward: 140.63
# Episode 206/500, Total Reward: 436.70
# Episode 207/500, Total Reward: 383.62
# Episode 208/500, Total Reward: 284.33
# Episode 209/500, Total Reward: 589.17
# Episode 210/500, Total Reward: 271.71
# Episode 211/500, Total Reward: 368.46
# Episode 212/500, Total Reward: 299.41
# Episode 213/500, Total Reward: 40.33
# Episode 214/500, Total Reward: 36.89
# Episode 215/500, Total Reward: 371.98
# Episode 216/500, Total Reward: 81.57
# Episode 217/500, Total Reward: 410.00
# Episode 218/500, Total Reward: 143.31
# Episode 219/500, Total Reward: 256.24
# Episode 220/500, Total Reward: 308.50
# Episode 221/500, Total Reward: 235.32
# Episode 222/500, Total Reward: 421.01
# Episode 223/500, Total Reward: 235.50
# Episode 224/500, Total Reward: 389.48
# Episode 225/500, Total Reward: 402.79
# Episode 226/500, Total Reward: 223.24
# Episode 227/500, Total Reward: 325.20
# Episode 228/500, Total Reward: 340.76
# Episode 229/500, Total Reward: 546.52
# Episode 230/500, Total Reward: 187.42
# Episode 231/500, Total Reward: 437.00
# Episode 232/500, Total Reward: 389.25
# Episode 233/500, Total Reward: 249.42
# Episode 234/500, Total Reward: 242.13
# Episode 235/500, Total Reward: 315.47
# Episode 236/500, Total Reward: 234.63
# Episode 237/500, Total Reward: 268.36
# Episode 238/500, Total Reward: 244.56
# Episode 239/500, Total Reward: 186.35
# Episode 240/500, Total Reward: 490.57
# Episode 241/500, Total Reward: 166.30
# Episode 242/500, Total Reward: 542.39
# Episode 243/500, Total Reward: 267.08
# Episode 244/500, Total Reward: 379.09
# Episode 245/500, Total Reward: 212.03
# Episode 246/500, Total Reward: 479.19
# Episode 247/500, Total Reward: 427.26
# Episode 248/500, Total Reward: 394.97
# Episode 249/500, Total Reward: 263.95
# Episode 250/500, Total Reward: 341.43
# Episode 251/500, Total Reward: 399.80
# Episode 252/500, Total Reward: 307.29
# Episode 253/500, Total Reward: 186.41
# Episode 254/500, Total Reward: 334.02
# Episode 255/500, Total Reward: 108.14
# Episode 256/500, Total Reward: 188.06
# Episode 257/500, Total Reward: 367.34
# Episode 258/500, Total Reward: 229.58
# Episode 259/500, Total Reward: 308.01
# Episode 260/500, Total Reward: 107.21
# Episode 261/500, Total Reward: 389.03
# Episode 262/500, Total Reward: 263.57
# Episode 263/500, Total Reward: 246.78
# Episode 264/500, Total Reward: 344.08
# Episode 265/500, Total Reward: 304.85
# Episode 266/500, Total Reward: 194.59
# Episode 267/500, Total Reward: 326.68
# Episode 268/500, Total Reward: 372.95
# Episode 269/500, Total Reward: 377.90
# Episode 270/500, Total Reward: 388.93
# Episode 271/500, Total Reward: 263.64
# Episode 272/500, Total Reward: 271.10
# Episode 273/500, Total Reward: 364.29
# Episode 274/500, Total Reward: 445.25
# Episode 275/500, Total Reward: 203.07
# Episode 276/500, Total Reward: 216.68
# Episode 277/500, Total Reward: 453.30
# Episode 278/500, Total Reward: 363.17
# Episode 279/500, Total Reward: 220.34
# Episode 280/500, Total Reward: 377.91
# Episode 281/500, Total Reward: 297.39
# Episode 282/500, Total Reward: 510.58
# Episode 283/500, Total Reward: 362.92
# Episode 284/500, Total Reward: 190.32
# Episode 285/500, Total Reward: 391.68
# Episode 286/500, Total Reward: 434.33
# Episode 287/500, Total Reward: 585.01
# Episode 288/500, Total Reward: 366.80
# Episode 289/500, Total Reward: 416.21
# Episode 290/500, Total Reward: 297.79
# Episode 291/500, Total Reward: 422.91
# Episode 292/500, Total Reward: 410.21
# Episode 293/500, Total Reward: 538.35
# Episode 294/500, Total Reward: 426.08
# Episode 295/500, Total Reward: 485.90
# Episode 296/500, Total Reward: 513.51
# Episode 297/500, Total Reward: 534.18
# Episode 298/500, Total Reward: 423.09
# Episode 299/500, Total Reward: 317.11
# Episode 300/500, Total Reward: 390.06
# Episode 301/500, Total Reward: 292.18
# Episode 302/500, Total Reward: 541.64
# Episode 303/500, Total Reward: 401.24
# Episode 304/500, Total Reward: 389.72
# Episode 305/500, Total Reward: 370.31
# Episode 306/500, Total Reward: 451.01
# Episode 307/500, Total Reward: 664.58
# Episode 308/500, Total Reward: 314.35
# Episode 309/500, Total Reward: 341.97
# Episode 310/500, Total Reward: 544.60
# Episode 311/500, Total Reward: 618.99
# Episode 312/500, Total Reward: 400.47
# Episode 313/500, Total Reward: 364.12
# Episode 314/500, Total Reward: 305.12
# Episode 315/500, Total Reward: 346.31
# Episode 316/500, Total Reward: 470.88
# Episode 317/500, Total Reward: 192.13
# Episode 318/500, Total Reward: 234.49
# Episode 319/500, Total Reward: 248.57
# Episode 320/500, Total Reward: 212.51
# Episode 321/500, Total Reward: 382.44
# Episode 322/500, Total Reward: 540.61
# Episode 323/500, Total Reward: 213.64
# Episode 324/500, Total Reward: 477.23
# Episode 325/500, Total Reward: 358.96
# Episode 326/500, Total Reward: 177.84
# Episode 327/500, Total Reward: 425.17
# Episode 328/500, Total Reward: 190.51
# Episode 329/500, Total Reward: 117.12
# Episode 330/500, Total Reward: 237.47
# Episode 331/500, Total Reward: 318.57
# Episode 332/500, Total Reward: 364.34
# Episode 333/500, Total Reward: 391.71
# Episode 334/500, Total Reward: 461.31
# Episode 335/500, Total Reward: 338.81
# Episode 336/500, Total Reward: 242.27
# Episode 337/500, Total Reward: 230.95
# Episode 338/500, Total Reward: 516.53
# Episode 339/500, Total Reward: 282.87
# Episode 340/500, Total Reward: 102.59
# Episode 341/500, Total Reward: 426.54
# Episode 342/500, Total Reward: 363.95
# Episode 343/500, Total Reward: 484.73
# Episode 344/500, Total Reward: 367.01
# Episode 345/500, Total Reward: 349.89
# Episode 346/500, Total Reward: 543.58
# Episode 347/500, Total Reward: 497.18
# Episode 348/500, Total Reward: 367.99
# Episode 349/500, Total Reward: 542.94
# Episode 350/500, Total Reward: 314.06
# Episode 351/500, Total Reward: 537.71
# Episode 352/500, Total Reward: 362.74
# Episode 353/500, Total Reward: 585.32
# Episode 354/500, Total Reward: 466.44
# Episode 355/500, Total Reward: 527.47
# Episode 356/500, Total Reward: 466.18
# Episode 357/500, Total Reward: 349.76
# Episode 358/500, Total Reward: 341.49
# Episode 359/500, Total Reward: 535.56
# Episode 360/500, Total Reward: 419.87
# Episode 361/500, Total Reward: 472.86
# Episode 362/500, Total Reward: 415.02
# Episode 363/500, Total Reward: 385.22
# Episode 364/500, Total Reward: 587.02
# Episode 365/500, Total Reward: 511.49
# Episode 366/500, Total Reward: 525.45
# Episode 367/500, Total Reward: 490.73
# Episode 368/500, Total Reward: 462.23
# Episode 369/500, Total Reward: 671.99
# Episode 370/500, Total Reward: 478.01
# Episode 371/500, Total Reward: 464.05
# Episode 372/500, Total Reward: 485.67
# Episode 373/500, Total Reward: 515.73
# Episode 374/500, Total Reward: 493.90
# Episode 375/500, Total Reward: 525.27
# Episode 376/500, Total Reward: 261.59
# Episode 377/500, Total Reward: 663.61
# Episode 378/500, Total Reward: 462.47
# Episode 379/500, Total Reward: 728.91
# Episode 380/500, Total Reward: 281.84
# Episode 381/500, Total Reward: 592.71
# Episode 382/500, Total Reward: 632.41
# Episode 383/500, Total Reward: 671.47
# Episode 384/500, Total Reward: 715.67
# Episode 385/500, Total Reward: 514.70
# Episode 386/500, Total Reward: 446.74
# Episode 387/500, Total Reward: 571.67
# Episode 388/500, Total Reward: 307.22
# Episode 389/500, Total Reward: 526.15
# Episode 390/500, Total Reward: 386.24
# Episode 391/500, Total Reward: 338.98
# Episode 392/500, Total Reward: 624.74
# Episode 393/500, Total Reward: 310.75
# Episode 394/500, Total Reward: 453.88
# Episode 395/500, Total Reward: 327.95
# Episode 396/500, Total Reward: 391.67
# Episode 397/500, Total Reward: 370.23
# Episode 398/500, Total Reward: 199.14
# Episode 399/500, Total Reward: 676.21
# Episode 400/500, Total Reward: 376.91
# Episode 401/500, Total Reward: 504.44
# Episode 402/500, Total Reward: 512.57
# Episode 403/500, Total Reward: 427.47
# Episode 404/500, Total Reward: 188.90
# Episode 405/500, Total Reward: 639.93
# Episode 406/500, Total Reward: 284.97
# Episode 407/500, Total Reward: 583.90
# Episode 408/500, Total Reward: 457.84
# Episode 409/500, Total Reward: 541.34
# Episode 410/500, Total Reward: 528.00
# Episode 411/500, Total Reward: 232.71
# Episode 412/500, Total Reward: 254.67
# Episode 413/500, Total Reward: 390.07
# Episode 414/500, Total Reward: 627.78
# Episode 415/500, Total Reward: 489.91
# Episode 416/500, Total Reward: 497.04
# Episode 417/500, Total Reward: 531.64
# Episode 418/500, Total Reward: 449.80
# Episode 419/500, Total Reward: 471.13
# Episode 420/500, Total Reward: 297.66
# Episode 421/500, Total Reward: 616.17
# Episode 422/500, Total Reward: 432.84
# Episode 423/500, Total Reward: 532.78
# Episode 424/500, Total Reward: 484.13
# Episode 425/500, Total Reward: 621.19
# Episode 426/500, Total Reward: 621.23
# Episode 427/500, Total Reward: 562.45
# Episode 428/500, Total Reward: 443.22
# Episode 429/500, Total Reward: 453.30
# Episode 430/500, Total Reward: 439.86
# Episode 431/500, Total Reward: 292.96
# Episode 432/500, Total Reward: 595.94
# Episode 433/500, Total Reward: 424.96
# Episode 434/500, Total Reward: 277.20
# Episode 435/500, Total Reward: 527.44
# Episode 436/500, Total Reward: 351.33
# Episode 437/500, Total Reward: 528.00
# Episode 438/500, Total Reward: 429.43
# Episode 439/500, Total Reward: 548.57
# Episode 440/500, Total Reward: 341.91
# Episode 441/500, Total Reward: 433.34
# Episode 442/500, Total Reward: 505.69
# Episode 443/500, Total Reward: 428.43
# Episode 444/500, Total Reward: 467.35
# Episode 445/500, Total Reward: 708.94
# Episode 446/500, Total Reward: 439.02
# Episode 447/500, Total Reward: 693.05
# Episode 448/500, Total Reward: 523.76
# Episode 449/500, Total Reward: 610.47
# Episode 450/500, Total Reward: 514.96
# Episode 451/500, Total Reward: 540.20
# Episode 452/500, Total Reward: 394.08
# Episode 453/500, Total Reward: 422.25
# Episode 454/500, Total Reward: 325.74
# Episode 455/500, Total Reward: 553.38
# Episode 456/500, Total Reward: 341.75
# Episode 457/500, Total Reward: 465.97
# Episode 458/500, Total Reward: 459.97
# Episode 459/500, Total Reward: 555.61
# Episode 460/500, Total Reward: 586.35
# Episode 461/500, Total Reward: 541.30
# Episode 462/500, Total Reward: 763.60
# Episode 463/500, Total Reward: 472.69
# Episode 464/500, Total Reward: 592.56
# Episode 465/500, Total Reward: 380.91
# Episode 466/500, Total Reward: 592.17
# Episode 467/500, Total Reward: 497.88
# Episode 468/500, Total Reward: 452.72
# Episode 469/500, Total Reward: 706.00
# Episode 470/500, Total Reward: 590.23
# Episode 471/500, Total Reward: 390.20
# Episode 472/500, Total Reward: 386.09
# Episode 473/500, Total Reward: 519.30
# Episode 474/500, Total Reward: 594.97
# Episode 475/500, Total Reward: 529.63
# Episode 476/500, Total Reward: 475.62
# Episode 477/500, Total Reward: 567.53
# Episode 478/500, Total Reward: 539.10
# Episode 479/500, Total Reward: 349.49
# Episode 480/500, Total Reward: 582.05
# Episode 481/500, Total Reward: 535.64
# Episode 482/500, Total Reward: 450.76
# Episode 483/500, Total Reward: 726.84
# Episode 484/500, Total Reward: 454.84
# Episode 485/500, Total Reward: 672.65
# Episode 486/500, Total Reward: 244.98
# Episode 487/500, Total Reward: 514.75
# Episode 488/500, Total Reward: 605.17
# Episode 489/500, Total Reward: 476.52
# Episode 490/500, Total Reward: 391.25
# Episode 491/500, Total Reward: 453.87
# Episode 492/500, Total Reward: 501.27
# Episode 493/500, Total Reward: 425.99
# Episode 494/500, Total Reward: 688.97
# Episode 495/500, Total Reward: 690.80
# Episode 496/500, Total Reward: 372.70
# Episode 497/500, Total Reward: 713.51
# Episode 498/500, Total Reward: 522.85
# Episode 499/500, Total Reward: 349.23
# Episode 500/500, Total Reward: 398.59

# %%
# Fetch and prepare unseen test data
df_test = fetch_data('NVDA', '2021-01-02', '2022-01-01')
df_test = add_indicators(df_test)
# Create new test environment
env_test = TradingEnv(df_test, initial_balance=10000, max_steps=len(df_test)-1)

# Run greedy policy on test environment
state = env_test.reset()
values_test = []
s = state
for _ in range(env_test.max_steps):
    action = policy_net(torch.tensor(s, dtype=torch.float32).unsqueeze(0).to(device)).argmax().item()
    s, _, done, _ = env_test.step(action)
    values_test.append(env_test.net_worth)
    if done:
        break

# Plot test performance
plt.figure(figsize=(10, 5))
plt.plot(range(len(values_test)), values_test, label='DQN Portfolio (Test)')
bh_test = df_test['Close'].iloc[:len(values_test)].values
bh_values_test = bh_test / bh_test[0] * env_test.initial_balance
plt.plot(range(len(bh_values_test)), bh_values_test, label='Buy & Hold (Test)')
plt.legend()
plt.title('Test Data: Portfolio Value Over Time')
plt.xlabel('Time Step')
plt.ylabel('Portfolio Value ($)')
plt.show()
# Out:
# /tmp/ipython-input-4-651389593.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # This model is very conservative and holds which should be improved you should work upon that ignore all the code below

# %%
actions = []
state = env_test.reset()
for _ in range(env_test.max_steps):
    action = policy_net(torch.tensor(state, dtype=torch.float32)
                        .unsqueeze(0).to(device)).argmax().item()
    actions.append(action)
    state, _, done, _ = env_test.step(action)
    if done: break

print("Action counts:", {a: actions.count(a) for a in set(actions)})

# %% [markdown]
# #Add a small penalty for each trade to discourage inaction‑only policies, or a bonus for correctly timed trades

# %%
# ## 2. Data Fetching and Indicator Computation

# %%

def fetch_data(symbol, start_date, end_date):
    df = yf.download(symbol, start=start_date, end=end_date)
    df = df[['Open', 'High', 'Low', 'Close', 'Volume']].dropna()
    return df

# %%

def add_indicators(df, window_sma=10, window_ema=10, window_rsi=14):
    df['SMA'] = df['Close'].rolling(window=window_sma).mean()
    df['EMA'] = df['Close'].ewm(span=window_ema, adjust=False).mean()
    # RSI calculation
    delta = df['Close'].diff()
    gain = delta.where(delta > 0, 0).rolling(window=window_rsi).mean()
    loss = -delta.where(delta < 0, 0).rolling(window=window_rsi).mean()
    rs = gain / loss
    df['RSI'] = 100 - (100 / (1 + rs))
    df.bfill(inplace=True)
    return df

# ## 3. Define Trading Environment with Reward Shaping

# %%
class TradingEnv(gym.Env):
    """Custom Gym environment for single-stock trading with trade penalty"""
    NVDAdata = {'render.modes': ['human']}

    def __init__(self, df, initial_balance=10000, max_steps=200, trade_penalty=0.1):
        super(TradingEnv, self).__init__()
        self.df = df.reset_index(drop=True)
        self.initial_balance = initial_balance
        self.max_steps = min(max_steps, len(df) - 1)
        self.trade_penalty = trade_penalty

        # Actions: 0 = hold, 1 = buy 1 share, 2 = sell 1 share
        self.action_space = spaces.Discrete(3)
        # Observation: [close, SMA, EMA, RSI, holdings, cash]
        obs_low = np.array([0, 0, 0, 0, 0, 0], dtype=np.float32)
        obs_high= np.array([np.inf, np.inf, np.inf, 100, np.inf, np.inf], dtype=np.float32)
        self.observation_space = spaces.Box(obs_low, obs_high, dtype=np.float32)

    def reset(self):
        self.balance = float(self.initial_balance)
        self.net_worth = float(self.initial_balance)
        self.shares_held = 0
        self.current_step = 0
        return self._get_obs()

    def _get_obs(self):
        row = self.df.loc[self.current_step]
        return np.array([
            row['Close'].item(), row['SMA'].item(), row['EMA'].item(), row['RSI'].item(),
            float(self.shares_held), float(self.balance)
        ], dtype=np.float32)

    def step(self, action):
        row = self.df.loc[self.current_step]
        price = row['Close'].item()
        prev_net_worth = self.net_worth

        # Execute action
        trade_cost = 0.0
        if action == 1 and self.balance >= price:
            self.shares_held += 1
            self.balance -= price
            trade_cost = self.trade_penalty
        elif action == 2 and self.shares_held > 0:
            self.shares_held -= 1
            self.balance += price
            trade_cost = self.trade_penalty

        self.current_step += 1
        done = self.current_step >= self.max_steps
        row_next = self.df.loc[self.current_step]
        self.net_worth = self.balance + self.shares_held * row_next['Close'].item()

        # Reward = change in net worth minus trade penalty
        reward = (self.net_worth - prev_net_worth) - trade_cost

        obs = self._get_obs()
        return obs, reward, done, {}

    def render(self, mode='human'):
        print(f"Step: {self.current_step}, Balance: {self.balance:.2f}, Shares: {self.shares_held}, Net Worth: {self.net_worth:.2f}")


# ## 4. Define DQN Agent

# %%
class DQN(nn.Module):
    def __init__(self, input_dim, action_dim):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(input_dim, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, action_dim)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# %%
Transition = namedtuple('Transition', ('state', 'action', 'reward', 'next_state', 'done'))
class ReplayBuffer:
    def __init__(self, capacity=10000):
        self.memory = deque(maxlen=capacity)
    def push(self, *args): self.memory.append(Transition(*args))
    def sample(self, batch_size): return random.sample(self.memory, batch_size)
    def __len__(self): return len(self.memory)


# ## 5. Training Loop

# %%
# Hyperparameters
episode_count = 300
nb_steps = 200
gamma = 0.99
epsilon_start = 1.0
epsilon_end = 0.01
epsilon_decay = 500
batch_size = 64
target_update = 10

# Fetch and prepare data
df = fetch_data('NVDA', '2020-01-01', '2021-01-01')
df = add_indicators(df)

# Use reward shaping penalty=0.1
env = TradingEnv(df, initial_balance=10000, max_steps=200, trade_penalty=0.1)

# Init networks and optimizer
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
policy_net = DQN(env.observation_space.shape[0], env.action_space.n).to(device)
target_net = DQN(env.observation_space.shape[0], env.action_space.n).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()
optimizer = optim.Adam(policy_net.parameters(), lr=1e-3)
memory = ReplayBuffer()
steps_done = 0

def select_action(state):
    global steps_done
    eps = epsilon_end + (epsilon_start - epsilon_end) * np.exp(-1. * steps_done / epsilon_decay)
    steps_done += 1
    if random.random() < eps:
        return random.randrange(env.action_space.n)
    with torch.no_grad():
        state_v = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
        return policy_net(state_v).argmax().item()

for episode in range(1, episode_count + 1):
    state = env.reset()
    total_reward = 0
    for t in range(nb_steps):
        action = select_action(state)
        next_state, reward, done, _ = env.step(action)
        memory.push(state, action, reward, next_state, done)
        state = next_state
        total_reward += reward
        if len(memory) >= batch_size:
            batch = Transition(*zip(*random.sample(memory.memory, batch_size)))
            s_b = torch.tensor(batch.state, dtype=torch.float32).to(device)
            a_b = torch.tensor(batch.action).unsqueeze(1).to(device)
            r_b = torch.tensor(batch.reward, dtype=torch.float32).unsqueeze(1).to(device)
            ns_b= torch.tensor(batch.next_state, dtype=torch.float32).to(device)
            d_b = torch.tensor(batch.done, dtype=torch.float32).unsqueeze(1).to(device)
            q = policy_net(s_b).gather(1, a_b)
            qn= target_net(ns_b).max(1)[0].detach().unsqueeze(1)
            y = r_b + gamma * qn * (1 - d_b)
            loss = nn.MSELoss()(q, y)
            optimizer.zero_grad(); loss.backward(); optimizer.step()
        if done: break
    if episode % target_update == 0: target_net.load_state_dict(policy_net.state_dict())
    print(f"Episode {episode}/{episode_count}, Total Reward: {total_reward:.2f}")


# ## 6. Evaluation on Training Data

# %%
state = env.reset(); values = []; s = state
for _ in range(env.max_steps):
    a = policy_net(torch.tensor(s, dtype=torch.float32).unsqueeze(0).to(device)).argmax().item()
    s, _, done, _ = env.step(a); values.append(env.net_worth)
    if done: break
plt.figure(figsize=(10,5))
plt.plot(range(len(values)), values, label='DQN (Train)')
bh = df['Close'].iloc[:len(values)].values; bhv = bh/bh[0]*env.initial_balance
plt.plot(range(len(bhv)), bhv, label='Buy&Hold (Train)'); plt.legend(); plt.title('Train'); plt.xlabel('Step'); plt.ylabel('Value'); plt.show()


# ## 7. Evaluation on Test Data

# %%
df_test = fetch_data('NVDA', '2021-01-02', '2022-01-01'); df_test = add_indicators(df_test)
env_test = TradingEnv(df_test, initial_balance=10000, max_steps=len(df_test)-1, trade_penalty=0.1)
state = env_test.reset(); values_test = []; s = state
for _ in range(env_test.max_steps):
    a = policy_net(torch.tensor(s, dtype=torch.float32).unsqueeze(0).to(device)).argmax().item()
    s, _, done, _ = env_test.step(a); values_test.append(env_test.net_worth)
    if done: break
plt.figure(figsize=(10,5))
plt.plot(range(len(values_test)), values_test, label='DQN (Test)')
bht = df_test['Close'].iloc[:len(values_test)].values; bhtv = bht/bht[0]*env_test.initial_balance
plt.plot(range(len(bhtv)), bhtv, label='Buy&Hold (Test)'); plt.legend(); plt.title('Test'); plt.xlabel('Step'); plt.ylabel('Value'); plt.show()

# %%
# ## 2. Data Fetching and Indicator Computation (with extra features)

# %%

def fetch_data(symbol, start_date, end_date):
    df = yf.download(symbol, start=start_date, end=end_date)
    df = df[['Open', 'High', 'Low', 'Close', 'Volume']].dropna()
    return df

# %%

def add_indicators(df, window_sma=10, window_ema=10, window_rsi=14):
    # Moving averages and RSI
    df['SMA'] = df['Close'].rolling(window=window_sma).mean()
    df['EMA'] = df['Close'].ewm(span=window_ema, adjust=False).mean()
    delta = df['Close'].diff()
    gain = delta.where(delta > 0, 0).rolling(window=window_rsi).mean()
    loss = -delta.where(delta < 0, 0).rolling(window=window_rsi).mean()
    rs = gain / loss
    df['RSI'] = 100 - (100 / (1 + rs))
    # Momentum features: 1-day and 5-day returns
    df['Ret1'] = df['Close'].pct_change(1)
    df['Ret5'] = df['Close'].pct_change(5)
    # Volume feature: 5-day average volume
    df['VolAvg'] = df['Volume'].rolling(window=5).mean()
    df.bfill(inplace=True)
    return df


# ## 3. Define Trading Environment with Reward Shaping

# %%
class TradingEnv(gym.Env):
    """Custom Gym environment with momentum & volume features and bonuses for correctly timed trades"""
    NVDAdata = {'render.modes': ['human']}

    def __init__(self, df, initial_balance=10000, max_steps=200, bonus=0.1):
        super(TradingEnv, self).__init__()
        self.df = df.reset_index(drop=True)
        self.initial_balance = initial_balance
        self.max_steps = min(max_steps, len(df) - 1)
        self.bonus = bonus

        # Actions: 0 = hold, 1 = buy, 2 = sell
        self.action_space = spaces.Discrete(3)
        # Observation: [Close, SMA, EMA, RSI, Ret1, Ret5, VolAvg, holdings, cash]
        obs_low = np.array([0, 0, 0, 0, -1, -1, 0, 0, 0], dtype=np.float32)
        obs_high= np.array([np.inf, np.inf, np.inf, 100, 1, 1, np.inf, np.inf, np.inf], dtype=np.float32)
        self.observation_space = spaces.Box(obs_low, obs_high, dtype=np.float32)

    def reset(self):
        self.balance = float(self.initial_balance)
        self.net_worth = float(self.initial_balance)
        self.shares_held = 0
        self.current_step = 0
        return self._get_obs()

    def _get_obs(self):
        row = self.df.loc[self.current_step]
        return np.array([
            row['Close'].item(), row['SMA'].item(), row['EMA'].item(), row['RSI'].item(),
            row['Ret1'].item(), row['Ret5'].item(), row['VolAvg'].item(),
            float(self.shares_held), float(self.balance)
        ], dtype=np.float32)

    def step(self, action):
        row = self.df.loc[self.current_step]
        price = row['Close'].item()
        prev_net_worth = self.net_worth

        # Execute action
        if action == 1 and self.balance >= price:
            self.shares_held += 1
            self.balance -= price
        elif action == 2 and self.shares_held > 0:
            self.shares_held -= 1
            self.balance += price

        self.current_step += 1
        done = self.current_step >= self.max_steps
        next_row = self.df.loc[self.current_step]
        self.net_worth = self.balance + self.shares_held * next_row['Close'].item()

        # Base reward = net worth change
        reward = self.net_worth - prev_net_worth
        # Bonus for correctly timed trades
        if action == 1 and next_row['Close'].item() > price:
            reward += self.bonus
        if action == 2 and next_row['Close'].item() < price:
            reward += self.bonus

        return self._get_obs(), reward, done, {}

    def render(self, mode='human'):
        print(f"Step: {self.current_step}, Balance: {self.balance:.2f}, Shares: {self.shares_held}, Net Worth: {self.net_worth:.2f}")


# ## 4. Define DQN Agent

# %%
class DQN(nn.Module):
    def __init__(self, input_dim, action_dim):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(input_dim, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, action_dim)
    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

Transition = namedtuple('Transition', ('state', 'action', 'reward', 'next_state', 'done'))
class ReplayBuffer:
    def __init__(self, capacity=10000): self.memory = deque(maxlen=capacity)
    def push(self, *args): self.memory.append(Transition(*args))
    def sample(self, bs): return random.sample(self.memory, bs)
    def __len__(self): return len(self.memory)


# ## 5. Training Loop

# %%
episode_count=500; nb_steps=200; gamma=0.99
epsilon_start=1.0; epsilon_end=0.05; epsilon_decay=2000
batch_size=64; target_update=10

# Fetch and prepare training data
df = fetch_data('NVDA','2020-01-01','2021-01-01')
df = add_indicators(df)
env = TradingEnv(df, bonus=0.1)

# Initialize DQN networks and optimizer
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
policy_net = DQN(env.observation_space.shape[0], env.action_space.n).to(device)
target_net = DQN(env.observation_space.shape[0], env.action_space.n).to(device)
target_net.load_state_dict(policy_net.state_dict()); target_net.eval()
optimizer = optim.Adam(policy_net.parameters(), lr=1e-3)
memory = ReplayBuffer()
steps_done = 0

def select_action(state):
    global steps_done
    eps = epsilon_end + (epsilon_start - epsilon_end) * np.exp(-1. * steps_done / epsilon_decay)
    steps_done += 1
    if random.random() < eps:
        return random.randrange(env.action_space.n)
    with torch.no_grad():
        return policy_net(torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)).argmax().item()

for ep in range(1, episode_count+1):
    state = env.reset(); total_reward = 0
    for t in range(nb_steps):
        action = select_action(state)
        next_state, reward, done, _ = env.step(action)
        memory.push(state, action, reward, next_state, done)
        state = next_state; total_reward += reward
        if len(memory) >= batch_size:
            batch = Transition(*zip(*memory.sample(batch_size)))
            s_b = torch.tensor(batch.state, dtype=torch.float32).to(device)
            a_b = torch.tensor(batch.action).unsqueeze(1).to(device)
            r_b = torch.tensor(batch.reward).unsqueeze(1).to(device)
            ns_b= torch.tensor(batch.next_state, dtype=torch.float32).to(device)
            d_b = torch.tensor(batch.done, dtype=torch.float32).unsqueeze(1).to(device)
            q = policy_net(s_b).gather(1, a_b)
            qn= target_net(ns_b).max(1)[0].detach().unsqueeze(1)
            y = r_b + gamma * qn * (1.0 - d_b)
            loss = nn.MSELoss()(q, y)
            optimizer.zero_grad(); loss.backward(); optimizer.step()
        if done: break
    if ep % target_update == 0: target_net.load_state_dict(policy_net.state_dict())
    print(f"Episode {ep}/{episode_count}, Total Reward: {total_reward:.2f}")


# ## 6. Evaluation on Training Data

# %%
state = env.reset(); vals = []
s = state
for _ in range(env.max_steps):
    a = policy_net(torch.tensor(s, dtype=torch.float32).unsqueeze(0).to(device)).argmax().item()
    s, _, done, _ = env.step(a); vals.append(env.net_worth)
    if done: break
plt.figure(figsize=(10,5))
plt.plot(range(len(vals)), vals, label='DQN (Train)')
bh = df['Close'].iloc[:len(vals)].values; bhv = bh/bh[0]*env.initial_balance
plt.plot(range(len(bhv)), bhv, label='Buy&Hold'); plt.legend(); plt.title('Training Data'); plt.xlabel('Step'); plt.ylabel('Value'); plt.show()

# %%
# ## 7. Evaluation on Test Data

# %%
df_test = fetch_data('NVDA','2021-01-02','2023-01-01'); df_test = add_indicators(df_test)
env_test = TradingEnv(df_test, bonus=0.1)
state = env_test.reset(); vals_test = []
s = state
for _ in range(env_test.max_steps):
    a = policy_net(torch.tensor(s, dtype=torch.float32).unsqueeze(0).to(device)).argmax().item()
    s, _, done, _ = env_test.step(a); vals_test.append(env_test.net_worth)
    if done: break
plt.figure(figsize=(10,5))
plt.plot(range(len(vals_test)), vals_test, label='DQN (Test)')
bh = df_test['Close'].iloc[:len(vals_test)].values; bhv = bh/bh[0]*env_test.initial_balance
plt.plot(range(len(bhv)), bhv, label='Buy&Hold'); plt.legend(); plt.title('Test Data'); plt.xlabel('Step'); plt.ylabel('Value'); plt.show()

# %%
# ==== Record actions during your test roll‑out ====
actions = []
state = env_test.reset()
for _ in range(env_test.max_steps):
    # select greedy action
    action = policy_net(
        torch.tensor(state, dtype=torch.float32)
             .unsqueeze(0).to(device)
    ).argmax().item()
    actions.append(action)
    state, _, done, _ = env_test.step(action)
    if done:
        break

# ==== Print counts ====
from collections import Counter
counts = Counter(actions)
print("Action counts on test run:", counts)
# e.g. Counter({0: 150, 1: 25, 2: 25})

# ==== (Optional) Plot actions over time ====
plt.figure(figsize=(10,3))
plt.plot(actions, marker='o', linestyle='', alpha=0.5)
plt.yticks([0,1,2], ["Hold","Buy","Sell"])
plt.title("Agent Actions Over Time (Test)")
plt.xlabel("Time Step")
plt.ylabel("Action")
plt.show()

# %%
# ## 2. Data Fetching and Indicator Computation (with extra features)

# %%

def fetch_data(symbol, start_date, end_date):
    df = yf.download(symbol, start=start_date, end=end_date)
    df = df[['Open', 'High', 'Low', 'Close', 'Volume']].dropna()
    return df

# %%

def add_indicators(df, window_sma=10, window_ema=10, window_rsi=14):
    # Moving averages and RSI
    df['SMA'] = df['Close'].rolling(window=window_sma).mean()
    df['EMA'] = df['Close'].ewm(span=window_ema, adjust=False).mean()
    delta = df['Close'].diff()
    gain = delta.where(delta > 0, 0).rolling(window=window_rsi).mean()
    loss = -delta.where(delta < 0, 0).rolling(window=window_rsi).mean()
    rs = gain / loss
    df['RSI'] = 100 - (100 / (1 + rs))
    # Momentum features: 1-day and 5-day returns
    df['Ret1'] = df['Close'].pct_change(1)
    df['Ret5'] = df['Close'].pct_change(5)
    # Volume feature: 5-day average volume
    df['VolAvg'] = df['Volume'].rolling(window=5).mean()
    df.bfill(inplace=True)
    return df


# ## 3. Define Trading Environment with Reward Shaping and Trade Penalty

# %%
class TradingEnv(gym.Env):
    """Custom Gym environment with momentum & volume features, bonuses, and penalties"""
    NVDAdata = {'render.modes': ['human']}

    def __init__(self, df, initial_balance=10000, max_steps=200, bonus=0.1, trade_penalty=0.1):
        super(TradingEnv, self).__init__()
        self.df = df.reset_index(drop=True)
        self.initial_balance = initial_balance
        self.max_steps = min(max_steps, len(df) - 1)
        self.bonus = bonus
        self.trade_penalty = trade_penalty

        # Actions: 0 = hold, 1 = buy, 2 = sell
        self.action_space = spaces.Discrete(3)
        # Observation: [Close, SMA, EMA, RSI, Ret1, Ret5, VolAvg, holdings, cash]
        obs_low = np.array([0, 0, 0, 0, -1, -1, 0, 0, 0], dtype=np.float32)
        obs_high= np.array([np.inf, np.inf, np.inf, 100, 1, 1, np.inf, np.inf, np.inf], dtype=np.float32)
        self.observation_space = spaces.Box(obs_low, obs_high, dtype=np.float32)

    def reset(self):
        self.balance = float(self.initial_balance)
        self.net_worth = float(self.initial_balance)
        self.shares_held = 0
        self.current_step = 0
        return self._get_obs()

    def _get_obs(self):
        row = self.df.loc[self.current_step]
        return np.array([
            row['Close'].item(), row['SMA'].item(), row['EMA'].item(), row['RSI'].item(),
            row['Ret1'].item(), row['Ret5'].item(), row['VolAvg'].item(),
            float(self.shares_held), float(self.balance)
        ], dtype=np.float32)

    def step(self, action):
        row = self.df.loc[self.current_step]
        price = row['Close'].item()
        prev_net_worth = self.net_worth

        # Execute action
        trade_cost = 0.0
        if action == 1 and self.balance >= price:
            self.shares_held += 1
            self.balance -= price
            trade_cost += self.trade_penalty
        elif action == 2 and self.shares_held > 0:
            self.shares_held -= 1
            self.balance += price
            trade_cost += self.trade_penalty

        # Advance step
        self.current_step += 1
        done = self.current_step >= self.max_steps
        next_row = self.df.loc[self.current_step]
        self.net_worth = self.balance + self.shares_held * next_row['Close'].item()

        # Base reward + bonuses
        reward = self.net_worth - prev_net_worth
        # Bonus for successfully timed trades
        if action == 1 and next_row['Close'].item() > price:
            reward += self.bonus
        if action == 2 and next_row['Close'].item() < price:
            reward += self.bonus
        # Subtract trade penalty
        reward -= trade_cost

        return self._get_obs(), reward, done, {}

    def render(self, mode='human'):
        print(f"Step: {self.current_step}, Balance: {self.balance:.2f}, Shares: {self.shares_held}, Net Worth: {self.net_worth:.2f}")

## 4. Define DQN Agent Define DQN Agent

# %%
class DQN(nn.Module):
    def __init__(self, input_dim, action_dim):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(input_dim, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, action_dim)
    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

Transition = namedtuple('Transition', ('state', 'action', 'reward', 'next_state', 'done'))
class ReplayBuffer:
    def __init__(self, capacity=10000): self.memory = deque(maxlen=capacity)
    def push(self, *args): self.memory.append(Transition(*args))
    def sample(self, bs): return random.sample(self.memory, bs)
    def __len__(self): return len(self.memory)


# ## 5. Training Loop

# %%
episode_count=500; nb_steps=200; gamma=0.99
epsilon_start=1.0; epsilon_end=0.05; epsilon_decay=2000
batch_size=64; target_update=10

# Fetch and prepare training data
df = fetch_data('NVDA','2020-01-01','2021-01-01')
df = add_indicators(df)
env = TradingEnv(df, bonus=0.1)

# Initialize DQN networks and optimizer
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
policy_net = DQN(env.observation_space.shape[0], env.action_space.n).to(device)
target_net = DQN(env.observation_space.shape[0], env.action_space.n).to(device)
target_net.load_state_dict(policy_net.state_dict()); target_net.eval()
optimizer = optim.Adam(policy_net.parameters(), lr=1e-3)
memory = ReplayBuffer()
steps_done = 0

def select_action(state):
    global steps_done
    eps = epsilon_end + (epsilon_start - epsilon_end) * np.exp(-1. * steps_done / epsilon_decay)
    steps_done += 1
    if random.random() < eps:
        return random.randrange(env.action_space.n)
    with torch.no_grad():
        return policy_net(torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)).argmax().item()

for ep in range(1, episode_count+1):
    state = env.reset(); total_reward = 0
    for t in range(nb_steps):
        action = select_action(state)
        next_state, reward, done, _ = env.step(action)
        memory.push(state, action, reward, next_state, done)
        state = next_state; total_reward += reward
        if len(memory) >= batch_size:
            batch = Transition(*zip(*memory.sample(batch_size)))
            s_b = torch.tensor(batch.state, dtype=torch.float32).to(device)
            a_b = torch.tensor(batch.action).unsqueeze(1).to(device)
            r_b = torch.tensor(batch.reward).unsqueeze(1).to(device)
            ns_b= torch.tensor(batch.next_state, dtype=torch.float32).to(device)
            d_b = torch.tensor(batch.done, dtype=torch.float32).unsqueeze(1).to(device)
            q = policy_net(s_b).gather(1, a_b)
            qn= target_net(ns_b).max(1)[0].detach().unsqueeze(1)
            y = r_b + gamma * qn * (1.0 - d_b)
            loss = nn.MSELoss()(q, y)
            optimizer.zero_grad(); loss.backward(); optimizer.step()
        if done: break
    if ep % target_update == 0: target_net.load_state_dict(policy_net.state_dict())
    print(f"Episode {ep}/{episode_count}, Total Reward: {total_reward:.2f}")


# ## 6. Evaluation on Training Data

# %%
state = env.reset(); vals = []
s = state
for _ in range(env.max_steps):
    a = policy_net(torch.tensor(s, dtype=torch.float32).unsqueeze(0).to(device)).argmax().item()
    s, _, done, _ = env.step(a); vals.append(env.net_worth)
    if done: break
plt.figure(figsize=(10,5))
plt.plot(range(len(vals)), vals, label='DQN (Train)')
bh = df['Close'].iloc[:len(vals)].values; bhv = bh/bh[0]*env.initial_balance
plt.plot(range(len(bhv)), bhv, label='Buy&Hold'); plt.legend(); plt.title('Training Data'); plt.xlabel('Step'); plt.ylabel('Value'); plt.show()


# ## 7. Evaluation on Test Data

# %%
df_test = fetch_data('NVDA','2021-01-02','2022-01-01'); df_test = add_indicators(df_test)
env_test = TradingEnv(df_test, bonus=0.1)
state = env_test.reset(); vals_test = []
s = state
for _ in range(env_test.max_steps):
    a = policy_net(torch.tensor(s, dtype=torch.float32).unsqueeze(0).to(device)).argmax().item()
    s, _, done, _ = env_test.step(a); vals_test.append(env_test.net_worth)
    if done: break
plt.figure(figsize=(10,5))
plt.plot(range(len(vals_test)), vals_test, label='DQN (Test)')
bh = df_test['Close'].iloc[:len(vals_test)].values; bhv = bh/bh[0]*env_test.initial_balance
plt.plot(range(len(bhv)), bhv, label='Buy&Hold'); plt.legend(); plt.title('Test Data'); plt.xlabel('Step'); plt.ylabel('Value'); plt.show()

# %%
# ==== Record actions during your test roll‑out ====
actions = []
state = env_test.reset()
for _ in range(env_test.max_steps):
    # select greedy action
    action = policy_net(
        torch.tensor(state, dtype=torch.float32)
             .unsqueeze(0).to(device)
    ).argmax().item()
    actions.append(action)
    state, _, done, _ = env_test.step(action)
    if done:
        break

# ==== Print counts ====
from collections import Counter
counts = Counter(actions)
print("Action counts on test run:", counts)
# e.g. Counter({0: 150, 1: 25, 2: 25})

# ==== (Optional) Plot actions over time ====
plt.figure(figsize=(10,3))
plt.plot(actions, marker='o', linestyle='', alpha=0.5)
plt.yticks([0,1,2], ["Hold","Buy","Sell"])
plt.title("Agent Actions Over Time (Test)")
plt.xlabel("Time Step")
plt.ylabel("Action")
plt.show()
